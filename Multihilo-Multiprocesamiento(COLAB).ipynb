# %%
#LUIS RONALDO ZABALAGA ESQUIA

# %%
# %%time
import threading
import datetime
class ThreadClass(threading.Thread):
    def run(self):
        now = datetime.datetime.now()
        print("%s dice hola en el tiempo: %s" %
        (self.getName(), now))
for i in range(2):
    t = ThreadClass()
    t.start()
# Out:
# Thread-11 dice hola en el tiempo: 2021-09-10 01:25:20.093343
# Thread-12 dice hola en el tiempo: 2021-09-10 01:25:20.096613
# CPU times: user 3.49 ms, sys: 131 µs, total: 3.62 ms
# Wall time: 4.28 ms

# %%
# %%time
from multiprocessing.dummy import Pool as ThreadPool
import urllib3
pool = ThreadPool(4)
urls = [
'https://www.python.org', 'https://www.yahoo.com',
'https://www.google.com', 'https://www.ujcm.edu.pe'
]
results = pool.map(urllib3.connection_from_url, urls)
for re in results:
    print(re)
pool.close()
pool.join()
# Out:
# HTTPSConnectionPool(host='www.python.org', port=443)
# HTTPSConnectionPool(host='www.yahoo.com', port=443)
# HTTPSConnectionPool(host='www.google.com', port=443)
# HTTPSConnectionPool(host='www.ujcm.edu.pe', port=443)
# CPU times: user 4.53 ms, sys: 367 µs, total: 4.9 ms
# Wall time: 105 ms

# %%
# %%time
import multiprocessing
def worker(num):
    """thread worker function"""
    print('Worker:', num )
    return
if __name__ == '__main__':
    jobs = []
    for i in range(5):
        p = multiprocessing.Process(target=worker, args=(i,))
        jobs.append(p)
        p.start()
# Out:
# Worker: 0
# Worker: 2
# CPU times: user 13.3 ms, sys: 18.3 ms, total: 31.6 ms
# Wall time: 33.8 ms
# Worker: 3
# Worker: 1
# Worker: 4

# %%
# %%time
import multiprocessing
import time
def worker():
    name = multiprocessing.current_process().name
    print (name, 'Starting' )
    time.sleep(2)
    print (name, 'Exiting' )
def my_service():
    name = multiprocessing.current_process().name
    print (name, 'Starting' )
    time.sleep(3)
    print (name, 'Exiting' )
if __name__ == '__main__':
    service = multiprocessing.Process(name='my_service'
    ,
    target=my_service)
    worker_1 = multiprocessing.Process(name='worker 1',
    target=worker)
    worker_2 = multiprocessing.Process(target=worker) # default name
    worker_1.start()
    worker_2.start()
    service.start()
# Out:
# Process-16 Starting
# CPU times: user 1.61 ms, sys: 13.8 ms, total: 15.4 ms
# Wall time: 15.2 ms
# worker 1 Starting
# my_service Starting

# %%
# %%time
import threading
# how many threads we want to start
THREADS_COUNT = 3
class Threaded_worker(threading.Thread):
    def __init__(self):
        threading.Thread.__init__(self)
    def run(self):
        threadName = threading.currentThread().getName()
        print("Hello, I am the thread %s" % threadName)
print('Starting %d threads...' % THREADS_COUNT)
for i in range(THREADS_COUNT):
    td = Threaded_worker()
    td.start()
# Out:
# Starting 3 threads...
# Hello, I am the thread Thread-27
# Hello, I am the thread Thread-28
# Hello, I am the thread Thread-29
# CPU times: user 3.43 ms, sys: 2.48 ms, total: 5.91 ms
# Wall time: 8.83 ms

# %%
# %%time
import multiprocessing
import os
# how many processes we want to start
WORKER_NUMBER = 3
def worker():
    PID = os.getpid()
    print ("Hello, I am the process with PID %d" % PID)
print ('Starting %d processes...' % WORKER_NUMBER)
jobs = []
for i in range(WORKER_NUMBER):
    p = multiprocessing.Process(target=worker, args=())
    jobs.append(p)
    p.start()
# Out:
# Starting 3 processes...
# Hello, I am the process with PID 198
# Hello, I am the process with PID 201
# CPU times: user 11.4 ms, sys: 13.8 ms, total: 25.2 ms
# Wall time: 28.2 ms
# Hello, I am the process with PID 204

# %%
# %%time
import threading
# how many threads we want to start
THREADS_COUNT = 2
class Threaded_worker(threading.Thread):
    def __init__(self):
        threading.Thread.__init__(self)
    def run(self):
        n = 250000000
        while n > 0:
            n -= 1
for i in range(THREADS_COUNT):
    td = Threaded_worker()
    td.start()
# Out:
# CPU times: user 27.4 ms, sys: 1.05 ms, total: 28.4 ms
# Wall time: 30.2 ms

# %%
# %%time
def countdown(n):
    while n > 0:
        n -= 1
COUNT = 500000000
countdown(COUNT)
# Out:
# CPU times: user 52.5 s, sys: 488 ms, total: 53 s
# Wall time: 52.6 s

# %%
# %%time
import threading
# how many threads we want to start
THREADS_COUNT = 2
class Threaded_worker(threading.Thread):
    def __init__(self):
        threading.Thread.__init__(self)
    def run(self):
        n = 250000000
        while n > 0:
            n -= 1
for i in range(THREADS_COUNT):
    td = Threaded_worker()
    td.start()
# Out:
# CPU times: user 22.8 ms, sys: 1.97 ms, total: 24.8 ms
# Wall time: 26.9 ms

# %%
# %%time
def countdown(n):
    while n > 0:
        n -= 1
COUNT = 500000000
countdown(COUNT)
# Out:
# CPU times: user 53.7 s, sys: 474 ms, total: 54.1 s
# Wall time: 53.7 s

# %%
# %%time
import multiprocessing
WORKER_NUMBER = 2
def worker():
    n = 250000000
    while n > 0:
        n -= 1
jobs = []
for i in range(WORKER_NUMBER):
    p = multiprocessing.Process(target=worker, args=())
    jobs.append(p)
    p.start()
# Out:
# CPU times: user 2.16 ms, sys: 8.08 ms, total: 10.2 ms
# Wall time: 21.4 ms
